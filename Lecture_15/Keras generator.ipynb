# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
 img=image.load_img("strange.jpg",target_size=(100,200))

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
np_img = image.img_to_array(img).astype(int)

# %%
plt.imshow(np_img)

# %%
imahe.ImageDataGenerator?
# Out:
# Object `imahe.ImageDataGenerator` not found.

# %%
 generator=image.ImageDataGenerator(horizontal_flip = True,
                          rotation_range =10,
                          shear_range = 2,
                          zoom_range =.5)

# %%
batch = np.array([np_img])

# %%
batch.shape
# Out:
# (1, 100, 200, 3)

# %%
gen = generator.flow(batch)

# %%
gen.next().shape
# Out:
# (1, 100, 200, 3)

# %%
plt.imshow(gen.next()[0]/255)
