# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
generator = image.ImageDataGenerator(horizontal_flip=True,
                        rotation_range=10,
                        shear_range=.2,
                        zoom_range=.5)

# %%
gen = generator.flow_from_directory("nums-dir")
# Out:
# Found 8 images belonging to 8 classes.

# %%
gen.class_indices
# Out:
# {'eight': 0,
#  'five': 1,
#  'four': 2,
#  'one': 3,
#  'seven': 4,
#  'six': 5,
#  'three': 6,
#  'two': 7}

# %%
images, values = gen.next()

# %%
images.shape
# Out:
# (8, 256, 256, 3)

# %%
len(values)
# Out:
# 8

# %%
out = gen.next()

# %%
for img, val in zip(images, values):
    plt.figure()
    plt.title(str(val))
    plt.imshow(img/255)
